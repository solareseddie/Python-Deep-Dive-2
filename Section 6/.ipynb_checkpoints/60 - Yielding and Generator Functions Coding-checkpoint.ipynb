# %% [markdown]
# Yielding and Generator Functions - Coding

# %%
import math

# %%
class FactIter:
    def __init__(self, n):
        self.n = n
        self.i = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.i >= self.n:
            raise StopIteration
        else:
            result = math.factorial(self.i)
            self.i += 1
            return result

# %%
fact_iter = FactIter(5)

# %%
list(fact_iter)
# Out:
# [1, 1, 2, 6, 24]

# %%
list(fact_iter)
# Out:
# []

# %%
next(fact_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 next(fact_iter)
#
# Cell In[2], line 11, in FactIter.__next__(self)
#       9     def __next__(self):
#      10         if self.i >= self.n:
# ---> 11             raise StopIteration
#      12         else:
#      13             result = math.factorial(self.i)
#      14             self.i += 1
#
# StopIteration:

# %%
def fact():
    i = 0
    def inner():
        nonlocal i
        result = math.factorial(i)
        i += 1
        return result
    return inner

# %%
f = fact()

# %%
f
# Out:
# <function __main__.fact.<locals>.inner()>

# %%
f()
# Out:
# 1

# %%
f()
# Out:
# 1

# %%
f()
# Out:
# 2

# %%
f()
# Out:
# 6

# %%
f = fact()
fact_iter = iter(f, math.factorial(5))

# %%
list(fact_iter)
# Out:
# [1, 1, 2, 6, 24]

# %%
list(fact_iter)
# Out:
# []

# %%
def my_func():
    print('line 1')
    yield 'Flying'
    print('line 2')
    yield 'Circus'

# %%
type(my_func)
# Out:
# function

# %%
f = my_func()

# %%
type(f)
# Out:
# generator

# %%
'__iter__' in dir(f)
# Out:
# True

# %%
'__next__' in dir(f)
# Out:
# True

# %%
iter(f) is f
# Out:
# True

# %%
f.__next__()
# Out:
# line 1
# 'Flying'

# %%
result = next(f)
# Out:
# line 2

# %%
result
# Out:
# 'Circus'

# %%
def silly():
    yield 'the'
    yield 'ministry'
    yield 'of'
    yield 'silly'
    yield 'walks'

# %%
silly
# Out:
# <function __main__.silly()>

# %%
gen = silly()

# %%
gen
# Out:
# <generator object silly at 0x0000026C069BF110>

# %%
for line in gen:
    print(line)
# Out:
# the
# ministry
# of
# silly
# walks

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
def silly():
    yield 'the'
    yield 'ministry'
    yield 'of'
    yield 'silly'
    if True:
        return 'Sorry, all done'
    yield 'walks'

# %%
gen = silly()

# %%
next(gen)
# Out:
# 'the'

# %%
next(gen)
# Out:
# 'ministry'

# %%
next(gen)
# Out:
# 'of'

# %%
next(gen)
# Out:
# 'silly'

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 next(gen)
#
# StopIteration: Sorry, all done

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
def fact(n):
    for i in range(n):
        print(math.factorial(i))

# %%
fact(5)
# Out:
# 1
# 1
# 2
# 6
# 24

# %%
def fact(n):
    for i in range(n):
        yield math.factorial(i)

# %%
fact
# Out:
# <function __main__.fact(n)>

# %%
fact(3)
# Out:
# <generator object fact at 0x0000026C06969490>

# %%
gen = fact(5)

# %%
gen
# Out:
# <generator object fact at 0x0000026C0696B440>

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 1

# %%
for num in gen:
    print(num)
# Out:
# 2
# 6
# 24

# %%
list(gen)
# Out:
# []

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
def squares(n):
    for i in range(n):
        yield i ** 2

# %%
sq = squares(5)

# %%
list(sq)
# Out:
# [0, 1, 4, 9, 16]

# %%
list(sq)
# Out:
# []
