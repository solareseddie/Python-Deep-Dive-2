# %% [markdown]
# 21. Assignments in Mutable Sequences - Lecture

# %%
l = [1, 2, 3, 4, 5]

# %%
print(id(l))
# Out:
# 2276433585728

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[0:3] = 'python'

# %%
print(id(l), l)
# Out:
# 2276433585728 ['p', 'y', 't', 'h', 'o', 'n', 4, 5]

# %%
l = [1, 2, 3, 4, 5]
print(id(l))
# Out:
# 2276433802368

# %%
l[2:5]
# Out:
# [3, 4, 5]

# %%
l[2:5] = []

# %%
print(id(l), l)
# Out:
# 2276433802368 [1, 2]

# %%
l = [1, 2, 3, 4, 5]
print(id(l), l)
# Out:
# 2276433621056 [1, 2, 3, 4, 5]

# %%
l[2:5] = ''
print(id(l), l)
# Out:
# 2276433621056 [1, 2]

# %%
len('')
# Out:
# 0

# %%
l = [1, 2, 3, 4, 5]
print(id(l), l)
# Out:
# 2276434176192 [1, 2, 3, 4, 5]

# %%
l[2:2]
# Out:
# []

# %%
s = slice(2, 2)

# %%
l[s]
# Out:
# []

# %%
s.start, s.stop
# Out:
# (2, 2)

# %%
l[2:2] = ('a', 100, 500)

# %%
print(id(l), l)
# Out:
# 2276434176192 [1, 2, 'a', 100, 500, 3, 4, 5]

# %%
t = (1, 2, 3, 4, 5)

# %%
t[0:3]
# Out:
# (1, 2, 3)

# %% [markdown]
# t[0:3] = ['a', 'b', 'c']

# %%
t[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 t[0] = 'a'
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# [1, 2, 'a', 100, 500, 3, 4, 5]

# %%
l[0] = 1

# %%
l[0]
# Out:
# 1

# %%
l = [1, 2, 3, 4, 5]
print(id(l), l)
# Out:
# 2276436708352 [1, 2, 3, 4, 5]

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[0:3] = {100, 'X', 'a'}

# %%
print(id(l), l)
# Out:
# 2276436708352 [100, 'X', 'a', 4, 5]

# %%
l = [1, 2, 3, 4, 5]
print(id(l), l)
# Out:
# 2276434167104 [1, 2, 3, 4, 5]

# %%
l[0:5:2]
# Out:
# [1, 3, 5]

# %%
l[0:5:2] ='abc'

# %%
print(id(l), l)
# Out:
# 2276434167104 ['a', 2, 'b', 4, 'c']

# %%
l[0:5:2] =[1, 3, 5]

# %%
print(id(l), l)
# Out:
# 2276434167104 [1, 2, 3, 4, 5]

# %%
l[0:5:2] =['a', 'b', 'c', 'd']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l[0:5:2] =['a', 'b', 'c', 'd']
#
# ValueError: attempt to assign sequence of size 4 to extended slice of size 3
