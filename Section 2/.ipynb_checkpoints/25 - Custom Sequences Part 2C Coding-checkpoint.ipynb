# %% [markdown]
# Custom Sequences - Part 2C Coding

# %%
import numbers

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point coordinates must be real numbers.')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

    def __len__(self):
        return len(self._pt)

    def __getitem__(self, s):
        return self._pt[s]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        self._pts[s] = [Point(*pt) for pt in value]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

# %%
p = Polygon((0, 0), (1, 1), (2, 2))
print(id(p), p)
# Out:
# 2251545806480 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0:2]
# Out:
# [Point(x=0, y=0), Point(x=1, y=1)]

# %%
p[0:2] = [(10, 10), Point(20, 20), [30, 30]]

# %%
print(id(p), p)
# Out:
# 2251545806480 Polygon(Point(x=10, y=10), Point(x=20, y=20), Point(x=30, y=30), Point(x=2, y=2))

# %%
p[0]
# Out:
# Point(x=10, y=10)

# %%
p[0] = Point(0, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 p[0] = Point(0, 0)
#
# Cell In[3], line 19, in Polygon.__setitem__(self, s, value)
#      18     def __setitem__(self, s, value):
# ---> 19         self._pts[s] = [Point(*pt) for pt in value]
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %%
for i in Point(10, 20):
    print(i)
# Out:
# 10
# 20

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        if isinstance(s, int):
            self._pts[s] = Point(*value)
        else:
            self._pts[s] = [Point(*pt) for pt in value]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

# %%
p = Polygon((0, 0), (1, 1), (2, 2))
print(id(p), p)
# Out:
# 2251548231392 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0] = Point(10, 10)

# %%
print(id(p), p)
# Out:
# 2251548231392 Polygon(Point(x=10, y=10), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0] = (-1, -1)

# %%
print(id(p), p)
# Out:
# 2251548231392 Polygon(Point(x=-1, y=-1), Point(x=1, y=1), Point(x=2, y=2))

# %%
l = [1, 2, 3, 4]
l[0:2] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 l = [1, 2, 3, 4]
# ----> 2 l[0:2] = 20
#
# TypeError: must assign iterable to extended slice

# %%
p
# Out:
# Polygon(Point(x=-1, y=-1), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0:2] = Point(20, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 p[0:2] = Point(20, 20)
#
# Cell In[13], line 22, in Polygon.__setitem__(self, s, value)
#      18     def __setitem__(self, s, value):
#      19         if isinstance(s, int):
#      20             self._pts[s] = Point(*value)
#      21         else:
# ---> 22             self._pts[s] = [Point(*pt) for pt in value]
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %%
p[0] = [Point(10, 10), Point(20, 20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 p[0] = [Point(10, 10), Point(20, 20)]
#
# Cell In[13], line 20, in Polygon.__setitem__(self, s, value)
#      18     def __setitem__(self, s, value):
#      19         if isinstance(s, int):
# ---> 20             self._pts[s] = Point(*value)
#      21         else:
#      22             self._pts[s] = [Point(*pt) for pt in value]
#
# Cell In[1], line 6, in Point.__init__(self, x, y)
#       2     def __init__(self, x, y):
#       3         if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
#       4             self._pt = (x, y)
#       5         else:
# ----> 6             raise TypeError('Point coordinates must be real numbers.')
#
# TypeError: Point coordinates must be real numbers.

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        try:
            rhs = [Point(*pt) for pt in value]
            is_single = False
        except TypeError:
            try:
                rhs = Point(*value)
                is_single = True
            except TypeError:
                raise TypeError('Invalid Point or iterable of Points')

        if (isinstance(s, int) and is_single) or (isinstance(s, slice) and not is_single):
                self._pts[s] = rhs
        else:
            raise TypeError('Incompatible index/slice assignment')

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

# %%
p = Polygon((0, 0), (1, 1), (2, 2))
print(id(p), p)
# Out:
# 2251548238784 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0] = [(0, 0), (1, 1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 p[0] = [(0, 0), (1, 1)]
#
# Cell In[24], line 32, in Polygon.__setitem__(self, s, value)
#      28
#      29         if (isinstance(s, int) and is_single) or (isinstance(s, slice) and not is_single):
#      30                 self._pts[s] = rhs
#      31         else:
# ---> 32             raise TypeError('Incompatible index/slice assignment')
#
# TypeError: Incompatible index/slice assignment

# %%
p[0:2] = Point(0, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 p[0:2] = Point(0, 0)
#
# Cell In[24], line 32, in Polygon.__setitem__(self, s, value)
#      28
#      29         if (isinstance(s, int) and is_single) or (isinstance(s, slice) and not is_single):
#      30                 self._pts[s] = rhs
#      31         else:
# ---> 32             raise TypeError('Incompatible index/slice assignment')
#
# TypeError: Incompatible index/slice assignment

# %%
p[0] = ('a', 'b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 27, in Polygon.__setitem__(self, s, value)
#      25                 is_single = True
#      26             except TypeError:
# ---> 27                 raise TypeError('Invalid Point or iterable of Points')
#      28
#
# TypeError: Point.__init__() missing 1 required positional argument: 'y'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 27, in Polygon.__setitem__(self, s, value)
#      25                 is_single = True
#      26             except TypeError:
# ---> 27                 raise TypeError('Invalid Point or iterable of Points')
#      28
#
# Cell In[1], line 6, in Point.__init__(self, x, y)
#       4             self._pt = (x, y)
#       5         else:
# ----> 6             raise TypeError('Point coordinates must be real numbers.')
#
# TypeError: Point coordinates must be real numbers.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 p[0] = ('a', 'b')
#
# Cell In[24], line 27, in Polygon.__setitem__(self, s, value)
#      23             try:
#      24                 rhs = Point(*value)
#      25                 is_single = True
#      26             except TypeError:
# ---> 27                 raise TypeError('Invalid Point or iterable of Points')
#      28
#      29         if (isinstance(s, int) and is_single) or (isinstance(s, slice) and not is_single):
#      30                 self._pts[s] = rhs
#
# TypeError: Invalid Point or iterable of Points

# %%
l = [1, 2, 3, 4, 5]

# %%
del l[0]

# %%
l
# Out:
# [2, 3, 4, 5]

# %%
del l[0:2]

# %%
l
# Out:
# [4, 5]

# %%
l.pop(0)
# Out:
# 4

# %%
l
# Out:
# [5]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        try:
            rhs = [Point(*pt) for pt in value]
            is_single = False
        except TypeError:
            try:
                rhs = Point(*value)
                is_single = True
            except TypeError:
                raise TypeError('Invalid Point or iterable of Points')

        if (isinstance(s, int) and is_single) or (isinstance(s, slice) and not is_single):
                self._pts[s] = rhs
        else:
            raise TypeError('Incompatible index/slice assignment')

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

    def __delitem__(self, s):
        del self._pts[s]

    def pop(self, i):
        return self._pts.pop(i)

    def clear(self):
        self._pts.clear()

# %%
p = Polygon((0, 0), (1, 1), (2, 2), (3, 3))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
del p[0]

# %%
p
# Out:
# Polygon(Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
del p[0:2]

# %%
p
# Out:
# Polygon(Point(x=3, y=3))

# %%
p.pop(0)
# Out:
# Point(x=3, y=3)

# %%
p
# Out:
# Polygon()

# %%
p = Polygon((0, 0), (1, 1), (2, 2), (3, 3))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
p.clear()

# %%
p
# Out:
# Polygon()
