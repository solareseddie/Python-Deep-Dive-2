# %% [markdown]
# Custom Sequences - Part 2A Coding

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'MyClass(name={self.name})'

    def __add__(self, other):
        print(f'You called + on {self} and {other}')
        return 'Hello from __add__'

    def __iadd__(self, other):
        print(f'You called += on {self} and {other}')
        return 'Hello from __iadd__'

# %%
c1 = MyClass('instance 1')
c2 = MyClass('instance 2')

# %%
c1 + c2
# Out:
# You called + on MyClass(name=instance 1) and MyClass(name=instance 2)
# 'Hello from __add__'

# %%
result = c1 + c2
# Out:
# You called + on MyClass(name=instance 1) and MyClass(name=instance 2)

# %%
print(result)
# Out:
# Hello from __add__

# %%
c1, c2
# Out:
# (MyClass(name=instance 1), MyClass(name=instance 2))

# %%
id(c1)
# Out:
# 2368482936144

# %%
c1 += c2
# Out:
# You called += on MyClass(name=instance 1) and MyClass(name=instance 2)

# %%
c1
# Out:
# 'Hello from __iadd__'

# %%
id(c1)
# Out:
# 2368484853616

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'MyClass(name={self.name})'

    def __add__(self, other):
        return MyClass(self.name + other.name)

    def __iadd__(self, other):
        if isinstance(other, MyClass):
            self.name += other.name
        else:
            self.name += other
        return self

# %%
c1 = MyClass('Eric')
c2 = MyClass('Idle')
print(id(c1), id(c2))
# Out:
# 2368484933712 2368482937424

# %%
result = c1 + c2

# %%
id(result), result
# Out:
# (2368482937744, MyClass(name=EricIdle))

# %%
c1 += c2

# %%
id(result), result
# Out:
# (2368482937744, MyClass(name=EricIdle))

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'MyClass(name={self.name})'

    def __add__(self, other):
        return MyClass(self.name + other.name)

    def __iadd__(self, other):
        if isinstance(other, MyClass):
            self.name += other.name
        else:
            self.name += other
        return self

    def __mul__(self, n):
        return MyClass(self.name * n)

    def __imul__(self, n):
        self.name *= n
        return self

# %%
c1 = MyClass('Eric')

# %%
id(c1)
# Out:
# 2368484934048

# %%
result = c1 * 3

# %%
id(result), result
# Out:
# (2368482938064, MyClass(name=EricEricEric))

# %%
c1 *= 3

# %%
id(c1), c1
# Out:
# (2368484934048, MyClass(name=EricEricEric))

# %%
c1 = MyClass('Eric')

# %%
c1 * 3
# Out:
# MyClass(name=EricEricEric)

# %%
3 * c1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 3 * c1
#
# TypeError: unsupported operand type(s) for *: 'int' and 'MyClass'

# %%
(3).__mul__(c1)
# Out:
# NotImplemented

# %%
c1.__rmul__(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 c1.__rmul__(3)
#
# AttributeError: 'MyClass' object has no attribute '__rmul__'

# %%
3 * c1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 3 * c1
#
# TypeError: unsupported operand type(s) for *: 'int' and 'MyClass'

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'MyClass(name={self.name})'

    def __add__(self, other):
        return MyClass(self.name + other.name)

    def __iadd__(self, other):
        if isinstance(other, MyClass):
            self.name += other.name
        else:
            self.name += other
        return self

    def __mul__(self, n):
        return MyClass(self.name * n)

    def __rmul__(self, n):
        return self.__mul__(n)

    def __imul__(self, n):
        self.name *= n
        return self

# %%
c1 = MyClass('Eric')

# %%
c1 * 3
# Out:
# MyClass(name=EricEricEric)

# %%
3 * c1
# Out:
# MyClass(name=EricEricEric)

# %%
l = [1, 2, 3, 4, 5]
s = 'python'

# %%
1 in l
# Out:
# True

# %%
'a' in s
# Out:
# False

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'MyClass(name={self.name})'

    def __add__(self, other):
        return MyClass(self.name + other.name)

    def __iadd__(self, other):
        if isinstance(other, MyClass):
            self.name += other.name
        else:
            self.name += other
        return self

    def __mul__(self, n):
        return MyClass(self.name * n)

    def __rmul__(self, n):
        return self.__mul__(n)

    def __imul__(self, n):
        self.name *= n
        return self

    def __contains__(self, value):
        return value in self.name

# %%
c1 = MyClass('Eric Idle')

# %%
'Eric' in c1
# Out:
# True

# %%
'I' in c1
# Out:
# True

# %%
'z' in c1
# Out:
# False
