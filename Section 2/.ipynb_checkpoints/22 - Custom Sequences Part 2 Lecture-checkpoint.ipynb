# %% [markdown]
# Custom Sequences - Part 2 Lecture

# %% [raw]
# Concatenation and In-Place Concatenation
#
# When dealing with the + and += operators in the context of sequences
# We usually expect them to mean concatenation
# But essentially it is just an overloaded definition of these operators
# We can overload the definition of these operators in our custom classes by using the methods:
#
# __add__
# __iadd__
#
# In general (but not necessarily), we expect:
#
# obj1 + ob2 -> obj1 and obj2 are of the same type (result is new object of same type)
# obj1 += obj2 -> obj2 can be any iterable (result is original obj1 memory reference, i.e. obj1 was mutated)

# %% [raw]
# Repetition and In-Place Repetition
#
# When dealing with the * and *= operators in the context of sequences
# We usually expect them to mean repetition
# But essentially it is just an overloaded definition of these operators
# We can overload the definition of these operators in our custom classes by using the methods:
#
# __mul__
# __imul__
#
# In general (but not necessarily), we expect:
#
# obj1 * n -> n is a non-negative integer (result is new object of same type)
# obj1 *= n -> n is a non-negative integer (result is original obj1 memory reference, i.e. obj1 was mutated)

# %% [raw]
# Assignment
#
# We saw that we can implement accessing elements in a custom sequence types
#
# __getitem__
# -> seq[n]
# -> seq[i:j]
# -> seq[i:j:k]
#
# We can handle assignments in a very similar way by implementing
#
# __setitem__
#
# There are a few restrictions to slices that we have already seen (with lists)
# - For any slice we could only assign an iter able
# - For extended slices only, both slice and iterable must have the same length
#
# Of course, since we are implementing in __setitem__ we could do whatever we want!

# %% [raw]
# Additional Sequence Functions and Operators
#
# There are operators and functions we can support:
#
# __contains__ ; in
# __delitem__ ; del
# __rmul__ ; n * seq
#
# The way that Python works when it encounters expressions such as:
#
# a + b
# a * b
#
# it first tries
#
# a.__add__(b)
# a.__mul__(b)
#
# if a does not support operation (TypeError), it then tries:
#
# b.__radd__(a)
# b.__rmul__(a)

# %% [raw]
# Implementing append, extend, pop
#
# Actually there is nothing special going on here.
# If we want to we can just implement methods of the same name (not special methods)
# and they can just behave the same way as we have seen for lists
