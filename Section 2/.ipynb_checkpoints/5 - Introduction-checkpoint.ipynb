# %% [markdown]
# Sequences

# %% [raw]
# What are sequences?
# Indexing starts at 0 - includes lower bound but exclude upper bound
# Slicing
# Slice objects
# Modifying Mutable Sequences
# Copying sequences (shallow and deep)
# Implementing custom sequence types
# Sorting
# List Comprehensions
