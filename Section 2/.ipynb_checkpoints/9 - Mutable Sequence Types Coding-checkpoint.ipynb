# %% [markdown]
# Mutable Sequence Type

# %%
l = [1, 2, 3, 4, 5]

# %%
print(id(l))
# Out:
# 2337553819520

# %%
l[0]
# Out:
# 1

# %%
l[0] = 'a'

# %%
l
# Out:
# ['a', 2, 3, 4, 5]

# %%
id(l)
# Out:
# 2337553819520

# %%
l.clear()

# %%
l
# Out:
# []

# %%
id(l)
# Out:
# 2337553819520

# %%
l = [1, 2, 3, 4, 5]

# %%
print(id(l), l)
# Out:
# 2337553845184 [1, 2, 3, 4, 5]

# %%
l = []

# %%
l
# Out:
# []

# %%
print(id(l))
# Out:
# 2337553654336

# %%
suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']

# %%
alias = suits

# %%
id(alias), id(suits)
# Out:
# (2337553814912, 2337553814912)

# %%
alias.clear()

# %%
alias
# Out:
# []

# %%
suits
# Out:
# []

# %%
suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']

# %%
def something(l):
    l.clear()

# %%
something(suits)

# %%
suits
# Out:
# []

# %%
l = [1, 2, 3, 4, 5]

# %%
id(l)
# Out:
# 2337553919232

# %%
l[0:2]
# Out:
# [1, 2]

# %%
l[0:2] = ('a', 'b', 'c', 'd')

# %%
l
# Out:
# ['a', 'b', 'c', 'd', 3, 4, 5]

# %%
id(l)
# Out:
# 2337553919232

# %%
l = [1, 2, 3]

# %%
id(l)
# Out:
# 2337553659840

# %%
l = l + [4]

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
id(l)
# Out:
# 2337532093760

# %%
l = [1, 2, 3]

# %%
id(l)
# Out:
# 2337553918592

# %%
result = l.append(4)

# %%
type(result)
# Out:
# NoneType

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
id(l)
# Out:
# 2337553918592

# %%
l.append([1, 2, 3])

# %%
l
# Out:
# [1, 2, 3, 4, [1, 2, 3]]

# %%
l = [1, 2, 3]
id(l)
# Out:
# 2337553973312

# %%
l.extend([4])

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.extend(['a', 'b', 'c'])

# %%
l
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c']

# %%
id(l)
# Out:
# 2337553973312

# %%
l = [1, 2, 3]

# %%
l.extend({'X', 'a', 'A', 100_000})

# %%
l
# Out:
# [1, 2, 3, 'X', 'A', 'a', 100000]

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 2337553982208

# %%
result = l.pop()

# %%
l
# Out:
# [1, 2, 3]

# %%
id(l)
# Out:
# 2337553982208

# %%
result
# Out:
# 4

# %%
l
# Out:
# [1, 2, 3]

# %%
l.pop(1)
# Out:
# 2

# %%
l
# Out:
# [1, 3]

# %%
id(l)
# Out:
# 2337553982208

# %%
l = [1, 2, 3]

# %%
del l[1]

# %%
l
# Out:
# [1, 3]

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 2337554201216

# %%
l.insert(1, 'a')

# %%
l
# Out:
# [1, 'a', 2, 3, 4]

# %%
id(l)
# Out:
# 2337554201216

# %%
l = [1, 2, 3]

# %%
l2 = l[::-1]

# %%
id(l), id(l2)
# Out:
# (2337554176960, 2337554191808)

# %%
l
# Out:
# [1, 2, 3]

# %%
l.reverse()

# %%
l
# Out:
# [3, 2, 1]

# %%
id(l)
# Out:
# 2337554176960

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 2337553824768

# %%
l2 = l[:]

# %%
l2
# Out:
# [1, 2, 3, 4]

# %%
id(l), id(l2)
# Out:
# (2337553824768, 2337553909504)

# %%
l3 = l.copy()

# %%
l3
# Out:
# [1, 2, 3, 4]

# %%
id(l3), id(l)
# Out:
# (2337554179264, 2337553824768)

# %%
l = [['a', 'b'], 'c', 'd']

# %%
id(l), id(l[0]), id(l[1])
# Out:
# (2337553982400, 2337554173184, 140727929667648)

# %%
l2 = l.copy()

# %%
id(l2)
# Out:
# 2337553652672

# %%
l2
# Out:
# [['a', 'b'], 'c', 'd']

# %%
id(l2[0]), id(l2[1])
# Out:
# (2337554173184, 140727929667648)

# %%
l
# Out:
# [['a', 'b'], 'c', 'd']

# %%
l2
# Out:
# [['a', 'b'], 'c', 'd']

# %%
id(l), id(l2)
# Out:
# (2337553982400, 2337553652672)

# %%
l[0].append('x')

# %%
l
# Out:
# [['a', 'b', 'x'], 'c', 'd']

# %%
l2
# Out:
# [['a', 'b', 'x'], 'c', 'd']
