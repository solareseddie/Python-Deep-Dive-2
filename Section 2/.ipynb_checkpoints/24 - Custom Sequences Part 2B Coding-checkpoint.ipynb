# %% [markdown]
# Custom Sequences - Part 2B Coding

# %%
from collections import namedtuple

# %%
Point = namedtuple('Point', 'x y')

# %%
p1 = Point(10.5, 3.2)

# %%
p1
# Out:
# Point(x=10.5, y=3.2)

# %%
p1 = Point('abc', [1, 2, 3])

# %%
p1
# Out:
# Point(x='abc', y=[1, 2, 3])

# %%
x, y = p1

# %%
x
# Out:
# 'abc'

# %%
y
# Out:
# [1, 2, 3]

# %%
import numbers

# %%
isinstance(10, numbers.Number)
# Out:
# True

# %%
isinstance('a', numbers.Number)
# Out:
# False

# %%
isinstance(10.5, numbers.Number)
# Out:
# True

# %%
isinstance(10+2j, numbers.Number)
# Out:
# True

# %%
isinstance(10, numbers.Real)
# Out:
# True

# %%
isinstance(10+2j, numbers.Real)
# Out:
# False

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point coordinates must be real numbers.')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

# %%
p1 = Point(10, 2.5)

# %%
p1
# Out:
# Point(x=10, y=2.5)

# %%
p1 = Point('abc', 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 p1 = Point('abc', 10)
#
# Cell In[19], line 6, in Point.__init__(self, x, y)
#       2     def __init__(self, x, y):
#       3         if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
#       4             self._pt = (x, y)
#       5         else:
# ----> 6             raise TypeError('Point coordinates must be real numbers.')
#
# TypeError: Point coordinates must be real numbers.

# %%
x, y = p1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 x, y = p1
#
# TypeError: cannot unpack non-iterable Point object

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point coordinates must be real numbers.')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

    def __len__(self):
        return len(self._pt)

    def __getitem__(self, s):
        return self._pt[s]

# %%
p1 = Point(10, 2)

# %%
x, y = p1

# %%
x
# Out:
# 10

# %%
y
# Out:
# 2

# %%
p2 = Point(*p1)

# %%
p1
# Out:
# Point(x=10, y=2)

# %%
p2
# Out:
# Point(x=10, y=2)

# %%
id(p1), id(p2)
# Out:
# (1923103556000, 1923101133712)

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        return f'Polygon({self._pts})'

# %%
p = Polygon((0, 0), Point(1, 1))

# %%
p
# Out:
# Polygon([Point(x=0, y=0), Point(x=1, y=1)])

# %%
p2 = Polygon([Point(x=0, y=0), Point(x=1, y=1)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 p2 = Polygon([Point(x=0, y=0), Point(x=1, y=1)])
#
# Cell In[33], line 4, in Polygon.__init__(self, *pts)
#       2     def __init__(self, *pts):
#       3         if pts:
# ----> 4             self._pts = [Point(*pt) for pt in pts]
#       5         else:
#       6             self._pts = []
#
# Cell In[24], line 6, in Point.__init__(self, x, y)
#       2     def __init__(self, x, y):
#       3         if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
#       4             self._pt = (x, y)
#       5         else:
# ----> 6             raise TypeError('Point coordinates must be real numbers.')
#
# TypeError: Point coordinates must be real numbers.

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

# %%
p = Polygon((0, 0), Point(1, 1))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
p1 = Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

# %%
p = Polygon((0, 0), (1, 1), (2, 2))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0]
# Out:
# Point(x=0, y=0)

# %%
p[0:2]
# Out:
# [Point(x=0, y=0), Point(x=1, y=1)]

# %%
p[::-1]
# Out:
# [Point(x=2, y=2), Point(x=1, y=1), Point(x=0, y=0)]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

# %%
p1 = Polygon((0, 0), (1, 1))
p2 = Polygon((2, 2), (3, 3))
id(p1), id(p2)
# Out:
# (1923103494688, 1923103494992)

# %%
result = p1 + p2
print(id(result), result)
# Out:
# 1923103056112 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def __iadd__(self, other):
        if isinstance(other, Polygon):
            self._pts = self._pts + other._pts
            return self
        else:
            raise TypeError('Can only concatenate with another Polygon')
