# %% [markdown]
# Copying Sequences - Coding

# %%
l1 = [1, 2, 3]

l1_copy = []
for item in l1:
    l1_copy.append(item)

print(l1_copy)
print(id(l1), id(l1_copy))
# Out:
# [1, 2, 3]
# 1797470572160 1797465208960

# %%
l1_copy = [item for item in l1]

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
id(l1_copy)
# Out:
# 1797470454912

# %%
l1_copy = l1.copy()

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
id(l1), id(l1_copy)
# Out:
# (1797470572160, 1797465208576)

# %%
l1_copy = list(l1)

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
id(l1_copy)
# Out:
# 1797470706112

# %%
t1 = (1, 2, 3)
l1_copy = list(t1)

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
t1 = (1, 2, 3)
t2 = tuple(t1)

print(id(t1), t1)
print(id(t2), t2)
# Out:
# 1797470429632 (1, 2, 3)
# 1797470429632 (1, 2, 3)

# %%
l1 = [1, 2, 3]
l2 = l1[:]

# %%
l1, l2
# Out:
# ([1, 2, 3], [1, 2, 3])

# %%
id(l1), id(l2)
# Out:
# (1797470577728, 1797470581952)

# %%
t1 = (1, 2, 3)
t2 = t1[:]

# %%
print(id(t1), t1)
print(id(t2), t2)
# Out:
# 1797470569664 (1, 2, 3)
# 1797470569664 (1, 2, 3)

# %%
s1 = 'python'
s2 = str(s1)

print(id(s1), s1)
print(id(s2), s2)
# Out:
# 1799540566384 python
# 1799540566384 python

# %%
s1 = 'python'
s2 = s1[:]

print(id(s1), s1)
print(id(s2), s2)
# Out:
# 1799540566384 python
# 1799540566384 python

# %%
import copy

# %%
l1 = [1, 2, 3]
l2 = copy.copy(l1)

print(id(l1), l1)
print(id(l2), l2)
# Out:
# 1797470713152 [1, 2, 3]
# 1797470713280 [1, 2, 3]

# %%
t1 = (1, 2, 3)
t2 = copy.copy(t1)

print(id(t1), t1)
print(id(t2), t2)
# Out:
# 1797470572544 (1, 2, 3)
# 1797470572544 (1, 2, 3)

# %%
v1 = [0, 0]
v2 = [0, 0]

line1 = [v1, v2]

# %%
line2 = line1.copy()

# %%
id(line1), id(line2)
# Out:
# (1797471534592, 1797471516672)

# %%
id(line1[0]), id(line2[0])
# Out:
# (1797471534848, 1797471534848)

# %%
line2 = [v for v in line1]

# %%
id(line1[0]), id(line2[0])
# Out:
# (1797471534848, 1797471534848)

# %%
id(line1[1]), id(line2[1])
# Out:
# (1797471517568, 1797471517568)

# %%
print(line1)
print(line2)
# Out:
# [[0, 0], [0, 0]]
# [[0, 0], [0, 0]]

# %%
line1[0][0] = 100

# %%
print(line1)
print(line2)
# Out:
# [[100, 0], [0, 0]]
# [[100, 0], [0, 0]]

# %%
line2 = [v.copy() for v in line1]

# %%
print(line1)
print(line2)
# Out:
# [[100, 0], [0, 0]]
# [[100, 0], [0, 0]]

# %%
id(line1), id(line2)
# Out:
# (1797471534592, 1797471515456)

# %%
id(line1[0]), id(line2[0])
# Out:
# (1797471534848, 1797470755008)

# %%
line1[0][0] = -10

# %%
line1
# Out:
# [[-10, 0], [0, 0]]

# %%
line2
# Out:
# [[100, 0], [0, 0]]

# %%
v1 = [1, 1]
v2 = [2, 2]
v3 = [3, 3]
v4 = [4, 4]

line1 = [v1, v2]
line2 = [v3, v4]

plane1 = [line1, line2]

# %%
plane1
# Out:
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
plane2 = [line.copy() for line in plane1]

# %%
print(plane1)
print(plane2)
# Out:
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
id(plane1[0]), id(plane2[0])
# Out:
# (1797470761984, 1797471615232)

# %%
print(plane1[0])
print(plane2[0])
# Out:
# [[1, 1], [2, 2]]
# [[1, 1], [2, 2]]

# %%
id(plane1[0][0]), id(plane2[0][0])
# Out:
# (1797471600448, 1797471600448)

# %%
plane1[0][0][0] = 100

# %%
print(plane1)
print(plane2)
# Out:
# [[[100, 1], [2, 2]], [[3, 3], [4, 4]]]
# [[[100, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
v1 = [1, 1]
v2 = [2, 2]
v3 = [3, 3]
v4 = [4, 4]

line1 = [v1, v2]
line2 = [v3, v4]

plane1 = [line1, line2]

# %%
plane2 = copy.deepcopy(plane1)

# %%
id(plane1), id(plane2)
# Out:
# (1797471616320, 1797471609984)

# %%
id(plane1[0]), id(plane2[0])
# Out:
# (1797470761024, 1797470580160)

# %%
id(plane1[0][0]), id(plane2[0][0])
# Out:
# (1797471611584, 1797471647808)

# %%
plane1[0][0][0] = 100

# %%
print(plane1)
print(plane2)
# Out:
# [[[100, 1], [2, 2]], [[3, 3], [4, 4]]]
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
class Point:
    def __init__(self, x, y):
        self.x = y
        self.y = y

    def __repr__(self):
        return f'Point({self.x}, {self.y})'

# %%
class Line:
    def __init__(self, p1, p2):
        self.p1 = p1
        self.p2 = p2

    def __repr__(self):
        return f'Line({self.p1.__repr()}, {self.p2.__repr()})'

# %%
p1 = Point(0, 0)
p2 = Point(10, 10)
line1 = Line(p1, p2)
line2 = copy.deepcopy(line1)

# %%
print(line1.p1, id(line1.p1))
print(line2.p1, id(line2.p1))
# Out:
# Point(0, 0) 1797471666592
# Point(0, 0) 1797468818640

# %%
p1 = Point(0, 0)
p2 = Point(10, 10)
line1 = Line(p1, p2)
line2 = copy.copy(line1)

# %%
print(line1.p1, id(line1.p1))
print(line2.p1, id(line2.p1))
# Out:
# Point(0, 0) 1797470718720
# Point(0, 0) 1797470718720
