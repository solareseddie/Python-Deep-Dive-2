# %% [markdown]
# Example 1 - Consuming Iterators Manually

# %%
s = 'I sleep all night, and I work all day'

# %%
for char in s:
    print(char)
# Out:
# I
#
# s
# l
# e
# e
# p
#
# a
# l
# l
#
# n
# i
# g
# h
# t
# ,
#
# a
# n
# d
#
# I
#
# w
# o
# r
# k
#
# a
# l
# l
#
# d
# a
# y

# %%
iter_s = iter(s)

# %%
iter_s

# %%
next(iter_s)
# Out:
# 'I'

# %%
iter_s.__next__()
# Out:
# ' '

# %%
next(iter_s)
# Out:
# 's'

# %%
next(iter_s)
# Out:
# 'l'

# %%
with open('cars.csv') as file:
    for line in file:
        print(line, end='')
# Out:
# car,mpg,cyl,disp,hp,drat,wt,qsec,vs,am,gear,carb
# string,double,int,double,double,double,double,double,int,int,int,int
# Mazda RX4,21,6,160,110,3.9,2.62,16.46,0,1,4,4
# Mazda RX4 Wag,21,6,160,110,3.9,2.875,17.02,0,1,4,4
# Datsun 710,22.8,4,108,93,3.85,2.32,18.61,1,1,4,1
# Hornet 4 Drive,21.4,6,258,110,3.08,3.215,19.44,1,0,3,1
# Hornet Sportabout,18.7,8,360,175,3.15,3.44,17.02,0,0,3,2
# Valiant,18.1,6,225,105,2.76,3.46,20.22,1,0,3,1
# Duster 360,14.3,8,360,245,3.21,3.57,15.84,0,0,3,4
# Merc 240D,24.4,4,146.7,62,3.69,3.19,20,1,0,4,2
# Merc 230,22.8,4,140.8,95,3.92,3.15,22.9,1,0,4,2
# Merc 280,19.2,6,167.6,123,3.92,3.44,18.3,1,0,4,4
# Merc 280C,17.8,6,167.6,123,3.92,3.44,18.9,1,0,4,4
# Merc 450SE,16.4,8,275.8,180,3.07,4.07,17.4,0,0,3,3
# Merc 450SL,17.3,8,275.8,180,3.07,3.73,17.6,0,0,3,3
# Merc 450SLC,15.2,8,275.8,180,3.07,3.78,18,0,0,3,3
# Cadillac Fleetwood,10.4,8,472,205,2.93,5.25,17.98,0,0,3,4
# Lincoln Continental,10.4,8,460,215,3,5.424,17.82,0,0,3,4
# Chrysler Imperial,14.7,8,440,230,3.23,5.345,17.42,0,0,3,4
# Fiat 128,32.4,4,78.7,66,4.08,2.2,19.47,1,1,4,1
# Honda Civic,30.4,4,75.7,52,4.93,1.615,18.52,1,1,4,2
# Toyota Corolla,33.9,4,71.1,65,4.22,1.835,19.9,1,1,4,1
# Toyota Corona,21.5,4,120.1,97,3.7,2.465,20.01,1,0,3,1
# Dodge Challenger,15.5,8,318,150,2.76,3.52,16.87,0,0,3,2
# AMC Javelin,15.2,8,304,150,3.15,3.435,17.3,0,0,3,2
# Camaro Z28,13.3,8,350,245,3.73,3.84,15.41,0,0,3,4
# Pontiac Firebird,19.2,8,400,175,3.08,3.845,17.05,0,0,3,2
# Fiat X1-9,27.3,4,79,66,4.08,1.935,18.9,1,1,4,1
# Porsche 914-2,26,4,120.3,91,4.43,2.14,16.7,0,1,5,2
# Lotus Europa,30.4,4,95.1,113,3.77,1.513,16.9,1,1,5,2
# Ford Pantera L,15.8,8,351,264,4.22,3.17,14.5,0,1,5,4
# Ferrari Dino,19.7,6,145,175,3.62,2.77,15.5,0,1,5,6
# Maserati Bora,15,8,301,335,3.54,3.57,14.6,0,1,5,8
# Volvo 142E,21.4,4,121,109,4.11,2.78,18.6,1,1,4,2

# %%
with open('cars.csv') as file:
    row_index = 0
    for line in file:
        if row_index == 0:
            headers = line.strip('\n').split(',')
            print('headers')
            print(headers)
        elif row_index == 1:
            data_types = line.strip('\n').split(',')
            print('types')
            print(data_types)
        else:
            data = line.strip('\n').split(',')
            print(data)
        row_index += 1
# Out:
# headers
# ['car', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
# types
# ['string', 'double', 'int', 'double', 'double', 'double', 'double', 'double', 'int', 'int', 'int', 'int']
# ['Mazda RX4', '21', '6', '160', '110', '3.9', '2.62', '16.46', '0', '1', '4', '4']
# ['Mazda RX4 Wag', '21', '6', '160', '110', '3.9', '2.875', '17.02', '0', '1', '4', '4']
# ['Datsun 710', '22.8', '4', '108', '93', '3.85', '2.32', '18.61', '1', '1', '4', '1']
# ['Hornet 4 Drive', '21.4', '6', '258', '110', '3.08', '3.215', '19.44', '1', '0', '3', '1']
# ['Hornet Sportabout', '18.7', '8', '360', '175', '3.15', '3.44', '17.02', '0', '0', '3', '2']
# ['Valiant', '18.1', '6', '225', '105', '2.76', '3.46', '20.22', '1', '0', '3', '1']
# ['Duster 360', '14.3', '8', '360', '245', '3.21', '3.57', '15.84', '0', '0', '3', '4']
# ['Merc 240D', '24.4', '4', '146.7', '62', '3.69', '3.19', '20', '1', '0', '4', '2']
# ['Merc 230', '22.8', '4', '140.8', '95', '3.92', '3.15', '22.9', '1', '0', '4', '2']
# ['Merc 280', '19.2', '6', '167.6', '123', '3.92', '3.44', '18.3', '1', '0', '4', '4']
# ['Merc 280C', '17.8', '6', '167.6', '123', '3.92', '3.44', '18.9', '1', '0', '4', '4']
# ['Merc 450SE', '16.4', '8', '275.8', '180', '3.07', '4.07', '17.4', '0', '0', '3', '3']
# ['Merc 450SL', '17.3', '8', '275.8', '180', '3.07', '3.73', '17.6', '0', '0', '3', '3']
# ['Merc 450SLC', '15.2', '8', '275.8', '180', '3.07', '3.78', '18', '0', '0', '3', '3']
# ['Cadillac Fleetwood', '10.4', '8', '472', '205', '2.93', '5.25', '17.98', '0', '0', '3', '4']
# ['Lincoln Continental', '10.4', '8', '460', '215', '3', '5.424', '17.82', '0', '0', '3', '4']
# ['Chrysler Imperial', '14.7', '8', '440', '230', '3.23', '5.345', '17.42', '0', '0', '3', '4']
# ['Fiat 128', '32.4', '4', '78.7', '66', '4.08', '2.2', '19.47', '1', '1', '4', '1']
# ['Honda Civic', '30.4', '4', '75.7', '52', '4.93', '1.615', '18.52', '1', '1', '4', '2']
# ['Toyota Corolla', '33.9', '4', '71.1', '65', '4.22', '1.835', '19.9', '1', '1', '4', '1']
# ['Toyota Corona', '21.5', '4', '120.1', '97', '3.7', '2.465', '20.01', '1', '0', '3', '1']
# ['Dodge Challenger', '15.5', '8', '318', '150', '2.76', '3.52', '16.87', '0', '0', '3', '2']
# ['AMC Javelin', '15.2', '8', '304', '150', '3.15', '3.435', '17.3', '0', '0', '3', '2']
# ['Camaro Z28', '13.3', '8', '350', '245', '3.73', '3.84', '15.41', '0', '0', '3', '4']
# ['Pontiac Firebird', '19.2', '8', '400', '175', '3.08', '3.845', '17.05', '0', '0', '3', '2']
# ['Fiat X1-9', '27.3', '4', '79', '66', '4.08', '1.935', '18.9', '1', '1', '4', '1']
# ['Porsche 914-2', '26', '4', '120.3', '91', '4.43', '2.14', '16.7', '0', '1', '5', '2']
# ['Lotus Europa', '30.4', '4', '95.1', '113', '3.77', '1.513', '16.9', '1', '1', '5', '2']
# ['Ford Pantera L', '15.8', '8', '351', '264', '4.22', '3.17', '14.5', '0', '1', '5', '4']
# ['Ferrari Dino', '19.7', '6', '145', '175', '3.62', '2.77', '15.5', '0', '1', '5', '6']
# ['Maserati Bora', '15', '8', '301', '335', '3.54', '3.57', '14.6', '0', '1', '5', '8']
# ['Volvo 142E', '21.4', '4', '121', '109', '4.11', '2.78', '18.6', '1', '1', '4', '2']

# %%
from collections import namedtuple
cars = []

with open('cars.csv') as file:
    row_index = 0
    for line in file:
        if row_index == 0:
            headers = line.strip('\n').split(',')
            Car = namedtuple('Car', headers)
        elif row_index == 1:
            data_types = line.strip('\n').split(',')
            print(data_types)
        else:
            data = line.strip('\n').split(',')
            car = Car(*data)
            cars.append(car)
        row_index += 1
# Out:
# ['string', 'double', 'int', 'double', 'double', 'double', 'double', 'double', 'int', 'int', 'int', 'int']

# %%
cars
# Out:
# [Car(car='Mazda RX4', mpg='21', cyl='6', disp='160', hp='110', drat='3.9', wt='2.62', qsec='16.46', vs='0', am='1', gear='4', carb='4'),
#  Car(car='Mazda RX4 Wag', mpg='21', cyl='6', disp='160', hp='110', drat='3.9', wt='2.875', qsec='17.02', vs='0', am='1', gear='4', carb='4'),
#  Car(car='Datsun 710', mpg='22.8', cyl='4', disp='108', hp='93', drat='3.85', wt='2.32', qsec='18.61', vs='1', am='1', gear='4', carb='1'),
#  Car(car='Hornet 4 Drive', mpg='21.4', cyl='6', disp='258', hp='110', drat='3.08', wt='3.215', qsec='19.44', vs='1', am='0', gear='3', carb='1'),
#  Car(car='Hornet Sportabout', mpg='18.7', cyl='8', disp='360', hp='175', drat='3.15', wt='3.44', qsec='17.02', vs='0', am='0', gear='3', carb='2'),
#  Car(car='Valiant', mpg='18.1', cyl='6', disp='225', hp='105', drat='2.76', wt='3.46', qsec='20.22', vs='1', am='0', gear='3', carb='1'),
#  Car(car='Duster 360', mpg='14.3', cyl='8', disp='360', hp='245', drat='3.21', wt='3.57', qsec='15.84', vs='0', am='0', gear='3', carb='4'),
#  Car(car='Merc 240D', mpg='24.4', cyl='4', disp='146.7', hp='62', drat='3.69', wt='3.19', qsec='20', vs='1', am='0', gear='4', carb='2'),
#  Car(car='Merc 230', mpg='22.8', cyl='4', disp='140.8', hp='95', drat='3.92', wt='3.15', qsec='22.9', vs='1', am='0', gear='4', carb='2'),
#  Car(car='Merc 280', mpg='19.2', cyl='6', disp='167.6', hp='123', drat='3.92', wt='3.44', qsec='18.3', vs='1', am='0', gear='4', carb='4'),
#  Car(car='Merc 280C', mpg='17.8', cyl='6', disp='167.6', hp='123', drat='3.92', wt='3.44', qsec='18.9', vs='1', am='0', gear='4', carb='4'),
#  Car(car='Merc 450SE', mpg='16.4', cyl='8', disp='275.8', hp='180', drat='3.07', wt='4.07', qsec='17.4', vs='0', am='0', gear='3', carb='3'),
#  Car(car='Merc 450SL', mpg='17.3', cyl='8', disp='275.8', hp='180', drat='3.07', wt='3.73', qsec='17.6', vs='0', am='0', gear='3', carb='3'),
#  Car(car='Merc 450SLC', mpg='15.2', cyl='8', disp='275.8', hp='180', drat='3.07', wt='3.78', qsec='18', vs='0', am='0', gear='3', carb='3'),
#  Car(car='Cadillac Fleetwood', mpg='10.4', cyl='8', disp='472', hp='205', drat='2.93', wt='5.25', qsec='17.98', vs='0', am='0', gear='3', carb='4'),
#  Car(car='Lincoln Continental', mpg='10.4', cyl='8', disp='460', hp='215', drat='3', wt='5.424', qsec='17.82', vs='0', am='0', gear='3', carb='4'),
#  Car(car='Chrysler Imperial', mpg='14.7', cyl='8', disp='440', hp='230', drat='3.23', wt='5.345', qsec='17.42', vs='0', am='0', gear='3', carb='4'),
#  Car(car='Fiat 128', mpg='32.4', cyl='4', disp='78.7', hp='66', drat='4.08', wt='2.2', qsec='19.47', vs='1', am='1', gear='4', carb='1'),
#  Car(car='Honda Civic', mpg='30.4', cyl='4', disp='75.7', hp='52', drat='4.93', wt='1.615', qsec='18.52', vs='1', am='1', gear='4', carb='2'),
#  Car(car='Toyota Corolla', mpg='33.9', cyl='4', disp='71.1', hp='65', drat='4.22', wt='1.835', qsec='19.9', vs='1', am='1', gear='4', carb='1'),
#  Car(car='Toyota Corona', mpg='21.5', cyl='4', disp='120.1', hp='97', drat='3.7', wt='2.465', qsec='20.01', vs='1', am='0', gear='3', carb='1'),
#  Car(car='Dodge Challenger', mpg='15.5', cyl='8', disp='318', hp='150', drat='2.76', wt='3.52', qsec='16.87', vs='0', am='0', gear='3', carb='2'),
#  Car(car='AMC Javelin', mpg='15.2', cyl='8', disp='304', hp='150', drat='3.15', wt='3.435', qsec='17.3', vs='0', am='0', gear='3', carb='2'),
#  Car(car='Camaro Z28', mpg='13.3', cyl='8', disp='350', hp='245', drat='3.73', wt='3.84', qsec='15.41', vs='0', am='0', gear='3', carb='4'),
#  Car(car='Pontiac Firebird', mpg='19.2', cyl='8', disp='400', hp='175', drat='3.08', wt='3.845', qsec='17.05', vs='0', am='0', gear='3', carb='2'),
#  Car(car='Fiat X1-9', mpg='27.3', cyl='4', disp='79', hp='66', drat='4.08', wt='1.935', qsec='18.9', vs='1', am='1', gear='4', carb='1'),
#  Car(car='Porsche 914-2', mpg='26', cyl='4', disp='120.3', hp='91', drat='4.43', wt='2.14', qsec='16.7', vs='0', am='1', gear='5', carb='2'),
#  Car(car='Lotus Europa', mpg='30.4', cyl='4', disp='95.1', hp='113', drat='3.77', wt='1.513', qsec='16.9', vs='1', am='1', gear='5', carb='2'),
#  Car(car='Ford Pantera L', mpg='15.8', cyl='8', disp='351', hp='264', drat='4.22', wt='3.17', qsec='14.5', vs='0', am='1', gear='5', carb='4'),
#  Car(car='Ferrari Dino', mpg='19.7', cyl='6', disp='145', hp='175', drat='3.62', wt='2.77', qsec='15.5', vs='0', am='1', gear='5', carb='6'),
#  Car(car='Maserati Bora', mpg='15', cyl='8', disp='301', hp='335', drat='3.54', wt='3.57', qsec='14.6', vs='0', am='1', gear='5', carb='8'),
#  Car(car='Volvo 142E', mpg='21.4', cyl='4', disp='121', hp='109', drat='4.11', wt='2.78', qsec='18.6', vs='1', am='1', gear='4', carb='2')]

# %%
def cast(data_type, value):
    if data_type == 'double':
        return float(value)
    if data_type == 'int':
        return int(value)
    else:
        return str(value)

# %%
from collections import namedtuple
cars = []

with open('cars.csv') as file:
    row_index = 0
    for line in file:
        if row_index == 0:
            headers = line.strip('\n').split(',')
            Car = namedtuple('Car', headers)
        elif row_index == 1:
            data_types = line.strip('\n').split(',')
            print(data_types)
        else:
            data = line.strip('\n').split(',')
            car = Car(*data)
            cars.append(car)
        row_index += 1
# Out:
# ['string', 'double', 'int', 'double', 'double', 'double', 'double', 'double', 'int', 'int', 'int', 'int']

# %%
data_types = ['string', 'double', 'int', 'double', 'double', 'double', 'double', 'double', 'int', 'int', 'int', 'int']
data_row = ['Volvo 142E', '21.4', '4', '121', '109', '4.11', '2.78', '18.6', '1', '1', '4', '2']

# %%
list(zip(data_types, data_row))
# Out:
# [('string', 'Volvo 142E'),
#  ('double', '21.4'),
#  ('int', '4'),
#  ('double', '121'),
#  ('double', '109'),
#  ('double', '4.11'),
#  ('double', '2.78'),
#  ('double', '18.6'),
#  ('int', '1'),
#  ('int', '1'),
#  ('int', '4'),
#  ('int', '2')]

# %%
def cast_row(data_types, data_row):
    return [cast(data_type, value)
            for data_type, value in zip(data_types, data_row)]

# %%
from collections import namedtuple
cars = []

with open('cars.csv') as file:
    row_index = 0
    for line in file:
        if row_index == 0:
            headers = line.strip('\n').split(',')
            Car = namedtuple('Car', headers)
        elif row_index == 1:
            data_types = line.strip('\n').split(',')
        else:
            data = line.strip('\n').split(',')
            data = cast_row(data_types, data)
            car = Car(*data)
            cars.append(car)
        row_index += 1

# %%
cars
# Out:
# [Car(car='Mazda RX4', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.62, qsec=16.46, vs=0, am=1, gear=4, carb=4),
#  Car(car='Mazda RX4 Wag', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.875, qsec=17.02, vs=0, am=1, gear=4, carb=4),
#  Car(car='Datsun 710', mpg=22.8, cyl=4, disp=108.0, hp=93.0, drat=3.85, wt=2.32, qsec=18.61, vs=1, am=1, gear=4, carb=1),
#  Car(car='Hornet 4 Drive', mpg=21.4, cyl=6, disp=258.0, hp=110.0, drat=3.08, wt=3.215, qsec=19.44, vs=1, am=0, gear=3, carb=1),
#  Car(car='Hornet Sportabout', mpg=18.7, cyl=8, disp=360.0, hp=175.0, drat=3.15, wt=3.44, qsec=17.02, vs=0, am=0, gear=3, carb=2),
#  Car(car='Valiant', mpg=18.1, cyl=6, disp=225.0, hp=105.0, drat=2.76, wt=3.46, qsec=20.22, vs=1, am=0, gear=3, carb=1),
#  Car(car='Duster 360', mpg=14.3, cyl=8, disp=360.0, hp=245.0, drat=3.21, wt=3.57, qsec=15.84, vs=0, am=0, gear=3, carb=4),
#  Car(car='Merc 240D', mpg=24.4, cyl=4, disp=146.7, hp=62.0, drat=3.69, wt=3.19, qsec=20.0, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 230', mpg=22.8, cyl=4, disp=140.8, hp=95.0, drat=3.92, wt=3.15, qsec=22.9, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 280', mpg=19.2, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.3, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 280C', mpg=17.8, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.9, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 450SE', mpg=16.4, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=4.07, qsec=17.4, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SL', mpg=17.3, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.73, qsec=17.6, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SLC', mpg=15.2, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.78, qsec=18.0, vs=0, am=0, gear=3, carb=3),
#  Car(car='Cadillac Fleetwood', mpg=10.4, cyl=8, disp=472.0, hp=205.0, drat=2.93, wt=5.25, qsec=17.98, vs=0, am=0, gear=3, carb=4),
#  Car(car='Lincoln Continental', mpg=10.4, cyl=8, disp=460.0, hp=215.0, drat=3.0, wt=5.424, qsec=17.82, vs=0, am=0, gear=3, carb=4),
#  Car(car='Chrysler Imperial', mpg=14.7, cyl=8, disp=440.0, hp=230.0, drat=3.23, wt=5.345, qsec=17.42, vs=0, am=0, gear=3, carb=4),
#  Car(car='Fiat 128', mpg=32.4, cyl=4, disp=78.7, hp=66.0, drat=4.08, wt=2.2, qsec=19.47, vs=1, am=1, gear=4, carb=1),
#  Car(car='Honda Civic', mpg=30.4, cyl=4, disp=75.7, hp=52.0, drat=4.93, wt=1.615, qsec=18.52, vs=1, am=1, gear=4, carb=2),
#  Car(car='Toyota Corolla', mpg=33.9, cyl=4, disp=71.1, hp=65.0, drat=4.22, wt=1.835, qsec=19.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Toyota Corona', mpg=21.5, cyl=4, disp=120.1, hp=97.0, drat=3.7, wt=2.465, qsec=20.01, vs=1, am=0, gear=3, carb=1),
#  Car(car='Dodge Challenger', mpg=15.5, cyl=8, disp=318.0, hp=150.0, drat=2.76, wt=3.52, qsec=16.87, vs=0, am=0, gear=3, carb=2),
#  Car(car='AMC Javelin', mpg=15.2, cyl=8, disp=304.0, hp=150.0, drat=3.15, wt=3.435, qsec=17.3, vs=0, am=0, gear=3, carb=2),
#  Car(car='Camaro Z28', mpg=13.3, cyl=8, disp=350.0, hp=245.0, drat=3.73, wt=3.84, qsec=15.41, vs=0, am=0, gear=3, carb=4),
#  Car(car='Pontiac Firebird', mpg=19.2, cyl=8, disp=400.0, hp=175.0, drat=3.08, wt=3.845, qsec=17.05, vs=0, am=0, gear=3, carb=2),
#  Car(car='Fiat X1-9', mpg=27.3, cyl=4, disp=79.0, hp=66.0, drat=4.08, wt=1.935, qsec=18.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Porsche 914-2', mpg=26.0, cyl=4, disp=120.3, hp=91.0, drat=4.43, wt=2.14, qsec=16.7, vs=0, am=1, gear=5, carb=2),
#  Car(car='Lotus Europa', mpg=30.4, cyl=4, disp=95.1, hp=113.0, drat=3.77, wt=1.513, qsec=16.9, vs=1, am=1, gear=5, carb=2),
#  Car(car='Ford Pantera L', mpg=15.8, cyl=8, disp=351.0, hp=264.0, drat=4.22, wt=3.17, qsec=14.5, vs=0, am=1, gear=5, carb=4),
#  Car(car='Ferrari Dino', mpg=19.7, cyl=6, disp=145.0, hp=175.0, drat=3.62, wt=2.77, qsec=15.5, vs=0, am=1, gear=5, carb=6),
#  Car(car='Maserati Bora', mpg=15.0, cyl=8, disp=301.0, hp=335.0, drat=3.54, wt=3.57, qsec=14.6, vs=0, am=1, gear=5, carb=8),
#  Car(car='Volvo 142E', mpg=21.4, cyl=4, disp=121.0, hp=109.0, drat=4.11, wt=2.78, qsec=18.6, vs=1, am=1, gear=4, carb=2)]

# %%
from collections import namedtuple
cars = []

with open('cars.csv') as file:
    file_iter = iter(file)
    headers = next(file_iter).strip('\n').split(',')
    Car = namedtuple('Car', headers)
    data_types = next(file_iter).strip('\n').split(',')

    for line in file_iter:
            data = line.strip('\n').split(',')
            data = cast_row(data_types, data)
            car = Car(*data)
            cars.append(car)

# %%
cars
# Out:
# [Car(car='Mazda RX4', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.62, qsec=16.46, vs=0, am=1, gear=4, carb=4),
#  Car(car='Mazda RX4 Wag', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.875, qsec=17.02, vs=0, am=1, gear=4, carb=4),
#  Car(car='Datsun 710', mpg=22.8, cyl=4, disp=108.0, hp=93.0, drat=3.85, wt=2.32, qsec=18.61, vs=1, am=1, gear=4, carb=1),
#  Car(car='Hornet 4 Drive', mpg=21.4, cyl=6, disp=258.0, hp=110.0, drat=3.08, wt=3.215, qsec=19.44, vs=1, am=0, gear=3, carb=1),
#  Car(car='Hornet Sportabout', mpg=18.7, cyl=8, disp=360.0, hp=175.0, drat=3.15, wt=3.44, qsec=17.02, vs=0, am=0, gear=3, carb=2),
#  Car(car='Valiant', mpg=18.1, cyl=6, disp=225.0, hp=105.0, drat=2.76, wt=3.46, qsec=20.22, vs=1, am=0, gear=3, carb=1),
#  Car(car='Duster 360', mpg=14.3, cyl=8, disp=360.0, hp=245.0, drat=3.21, wt=3.57, qsec=15.84, vs=0, am=0, gear=3, carb=4),
#  Car(car='Merc 240D', mpg=24.4, cyl=4, disp=146.7, hp=62.0, drat=3.69, wt=3.19, qsec=20.0, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 230', mpg=22.8, cyl=4, disp=140.8, hp=95.0, drat=3.92, wt=3.15, qsec=22.9, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 280', mpg=19.2, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.3, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 280C', mpg=17.8, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.9, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 450SE', mpg=16.4, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=4.07, qsec=17.4, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SL', mpg=17.3, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.73, qsec=17.6, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SLC', mpg=15.2, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.78, qsec=18.0, vs=0, am=0, gear=3, carb=3),
#  Car(car='Cadillac Fleetwood', mpg=10.4, cyl=8, disp=472.0, hp=205.0, drat=2.93, wt=5.25, qsec=17.98, vs=0, am=0, gear=3, carb=4),
#  Car(car='Lincoln Continental', mpg=10.4, cyl=8, disp=460.0, hp=215.0, drat=3.0, wt=5.424, qsec=17.82, vs=0, am=0, gear=3, carb=4),
#  Car(car='Chrysler Imperial', mpg=14.7, cyl=8, disp=440.0, hp=230.0, drat=3.23, wt=5.345, qsec=17.42, vs=0, am=0, gear=3, carb=4),
#  Car(car='Fiat 128', mpg=32.4, cyl=4, disp=78.7, hp=66.0, drat=4.08, wt=2.2, qsec=19.47, vs=1, am=1, gear=4, carb=1),
#  Car(car='Honda Civic', mpg=30.4, cyl=4, disp=75.7, hp=52.0, drat=4.93, wt=1.615, qsec=18.52, vs=1, am=1, gear=4, carb=2),
#  Car(car='Toyota Corolla', mpg=33.9, cyl=4, disp=71.1, hp=65.0, drat=4.22, wt=1.835, qsec=19.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Toyota Corona', mpg=21.5, cyl=4, disp=120.1, hp=97.0, drat=3.7, wt=2.465, qsec=20.01, vs=1, am=0, gear=3, carb=1),
#  Car(car='Dodge Challenger', mpg=15.5, cyl=8, disp=318.0, hp=150.0, drat=2.76, wt=3.52, qsec=16.87, vs=0, am=0, gear=3, carb=2),
#  Car(car='AMC Javelin', mpg=15.2, cyl=8, disp=304.0, hp=150.0, drat=3.15, wt=3.435, qsec=17.3, vs=0, am=0, gear=3, carb=2),
#  Car(car='Camaro Z28', mpg=13.3, cyl=8, disp=350.0, hp=245.0, drat=3.73, wt=3.84, qsec=15.41, vs=0, am=0, gear=3, carb=4),
#  Car(car='Pontiac Firebird', mpg=19.2, cyl=8, disp=400.0, hp=175.0, drat=3.08, wt=3.845, qsec=17.05, vs=0, am=0, gear=3, carb=2),
#  Car(car='Fiat X1-9', mpg=27.3, cyl=4, disp=79.0, hp=66.0, drat=4.08, wt=1.935, qsec=18.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Porsche 914-2', mpg=26.0, cyl=4, disp=120.3, hp=91.0, drat=4.43, wt=2.14, qsec=16.7, vs=0, am=1, gear=5, carb=2),
#  Car(car='Lotus Europa', mpg=30.4, cyl=4, disp=95.1, hp=113.0, drat=3.77, wt=1.513, qsec=16.9, vs=1, am=1, gear=5, carb=2),
#  Car(car='Ford Pantera L', mpg=15.8, cyl=8, disp=351.0, hp=264.0, drat=4.22, wt=3.17, qsec=14.5, vs=0, am=1, gear=5, carb=4),
#  Car(car='Ferrari Dino', mpg=19.7, cyl=6, disp=145.0, hp=175.0, drat=3.62, wt=2.77, qsec=15.5, vs=0, am=1, gear=5, carb=6),
#  Car(car='Maserati Bora', mpg=15.0, cyl=8, disp=301.0, hp=335.0, drat=3.54, wt=3.57, qsec=14.6, vs=0, am=1, gear=5, carb=8),
#  Car(car='Volvo 142E', mpg=21.4, cyl=4, disp=121.0, hp=109.0, drat=4.11, wt=2.78, qsec=18.6, vs=1, am=1, gear=4, carb=2)]

# %%
from collections import namedtuple

with open('cars.csv') as file:
    file_iter = iter(file)
    headers = next(file_iter).strip('\n').split(',')
    Car = namedtuple('Car', headers)
    data_types = next(file_iter).strip('\n').split(',')

    cars = [Car(*cast_row(data_types, line.strip('\n').split(','))) for line in file_iter]

# %%
cars
# Out:
# [Car(car='Mazda RX4', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.62, qsec=16.46, vs=0, am=1, gear=4, carb=4),
#  Car(car='Mazda RX4 Wag', mpg=21.0, cyl=6, disp=160.0, hp=110.0, drat=3.9, wt=2.875, qsec=17.02, vs=0, am=1, gear=4, carb=4),
#  Car(car='Datsun 710', mpg=22.8, cyl=4, disp=108.0, hp=93.0, drat=3.85, wt=2.32, qsec=18.61, vs=1, am=1, gear=4, carb=1),
#  Car(car='Hornet 4 Drive', mpg=21.4, cyl=6, disp=258.0, hp=110.0, drat=3.08, wt=3.215, qsec=19.44, vs=1, am=0, gear=3, carb=1),
#  Car(car='Hornet Sportabout', mpg=18.7, cyl=8, disp=360.0, hp=175.0, drat=3.15, wt=3.44, qsec=17.02, vs=0, am=0, gear=3, carb=2),
#  Car(car='Valiant', mpg=18.1, cyl=6, disp=225.0, hp=105.0, drat=2.76, wt=3.46, qsec=20.22, vs=1, am=0, gear=3, carb=1),
#  Car(car='Duster 360', mpg=14.3, cyl=8, disp=360.0, hp=245.0, drat=3.21, wt=3.57, qsec=15.84, vs=0, am=0, gear=3, carb=4),
#  Car(car='Merc 240D', mpg=24.4, cyl=4, disp=146.7, hp=62.0, drat=3.69, wt=3.19, qsec=20.0, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 230', mpg=22.8, cyl=4, disp=140.8, hp=95.0, drat=3.92, wt=3.15, qsec=22.9, vs=1, am=0, gear=4, carb=2),
#  Car(car='Merc 280', mpg=19.2, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.3, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 280C', mpg=17.8, cyl=6, disp=167.6, hp=123.0, drat=3.92, wt=3.44, qsec=18.9, vs=1, am=0, gear=4, carb=4),
#  Car(car='Merc 450SE', mpg=16.4, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=4.07, qsec=17.4, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SL', mpg=17.3, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.73, qsec=17.6, vs=0, am=0, gear=3, carb=3),
#  Car(car='Merc 450SLC', mpg=15.2, cyl=8, disp=275.8, hp=180.0, drat=3.07, wt=3.78, qsec=18.0, vs=0, am=0, gear=3, carb=3),
#  Car(car='Cadillac Fleetwood', mpg=10.4, cyl=8, disp=472.0, hp=205.0, drat=2.93, wt=5.25, qsec=17.98, vs=0, am=0, gear=3, carb=4),
#  Car(car='Lincoln Continental', mpg=10.4, cyl=8, disp=460.0, hp=215.0, drat=3.0, wt=5.424, qsec=17.82, vs=0, am=0, gear=3, carb=4),
#  Car(car='Chrysler Imperial', mpg=14.7, cyl=8, disp=440.0, hp=230.0, drat=3.23, wt=5.345, qsec=17.42, vs=0, am=0, gear=3, carb=4),
#  Car(car='Fiat 128', mpg=32.4, cyl=4, disp=78.7, hp=66.0, drat=4.08, wt=2.2, qsec=19.47, vs=1, am=1, gear=4, carb=1),
#  Car(car='Honda Civic', mpg=30.4, cyl=4, disp=75.7, hp=52.0, drat=4.93, wt=1.615, qsec=18.52, vs=1, am=1, gear=4, carb=2),
#  Car(car='Toyota Corolla', mpg=33.9, cyl=4, disp=71.1, hp=65.0, drat=4.22, wt=1.835, qsec=19.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Toyota Corona', mpg=21.5, cyl=4, disp=120.1, hp=97.0, drat=3.7, wt=2.465, qsec=20.01, vs=1, am=0, gear=3, carb=1),
#  Car(car='Dodge Challenger', mpg=15.5, cyl=8, disp=318.0, hp=150.0, drat=2.76, wt=3.52, qsec=16.87, vs=0, am=0, gear=3, carb=2),
#  Car(car='AMC Javelin', mpg=15.2, cyl=8, disp=304.0, hp=150.0, drat=3.15, wt=3.435, qsec=17.3, vs=0, am=0, gear=3, carb=2),
#  Car(car='Camaro Z28', mpg=13.3, cyl=8, disp=350.0, hp=245.0, drat=3.73, wt=3.84, qsec=15.41, vs=0, am=0, gear=3, carb=4),
#  Car(car='Pontiac Firebird', mpg=19.2, cyl=8, disp=400.0, hp=175.0, drat=3.08, wt=3.845, qsec=17.05, vs=0, am=0, gear=3, carb=2),
#  Car(car='Fiat X1-9', mpg=27.3, cyl=4, disp=79.0, hp=66.0, drat=4.08, wt=1.935, qsec=18.9, vs=1, am=1, gear=4, carb=1),
#  Car(car='Porsche 914-2', mpg=26.0, cyl=4, disp=120.3, hp=91.0, drat=4.43, wt=2.14, qsec=16.7, vs=0, am=1, gear=5, carb=2),
#  Car(car='Lotus Europa', mpg=30.4, cyl=4, disp=95.1, hp=113.0, drat=3.77, wt=1.513, qsec=16.9, vs=1, am=1, gear=5, carb=2),
#  Car(car='Ford Pantera L', mpg=15.8, cyl=8, disp=351.0, hp=264.0, drat=4.22, wt=3.17, qsec=14.5, vs=0, am=1, gear=5, carb=4),
#  Car(car='Ferrari Dino', mpg=19.7, cyl=6, disp=145.0, hp=175.0, drat=3.62, wt=2.77, qsec=15.5, vs=0, am=1, gear=5, carb=6),
#  Car(car='Maserati Bora', mpg=15.0, cyl=8, disp=301.0, hp=335.0, drat=3.54, wt=3.57, qsec=14.6, vs=0, am=1, gear=5, carb=8),
#  Car(car='Volvo 142E', mpg=21.4, cyl=4, disp=121.0, hp=109.0, drat=4.11, wt=2.78, qsec=18.6, vs=1, am=1, gear=4, carb=2)]
