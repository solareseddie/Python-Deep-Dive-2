# %% [markdown]
# Iterating Collections - Coding

# %%
s = {'x', 'y', 'b', 'c', 'a'}

# %%
for item in s:
    print(item)
# Out:
# y
# a
# c
# b
# x

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
class Squares:
    def __init__(self):
        self.i = 0

    def next_(self):
        result = self.i ** 2
        self.i += 1
        return result

# %%
sq = Squares()

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq.next_()
# Out:
# 4

# %%
sq.next_()
# Out:
# 9

# %%
sq.next_()
# Out:
# 16

# %%
sq = Squares()

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq.next_()
# Out:
# 4

# %%
sq = Squares()

# %%
for i in range(5):
    print(sq.next_())
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
class Squares:
    def __init__(self, length):
        self.i = 0
        self.length = length

    def __len__(self):
        return self.length
    
    def next_(self):
        if self.i >= self.length:
            raise StopIteration
        else:
            result = self.i ** 2
            self.i += 1
            return result

# %%
sq = Squares(3)

# %%
len(sq)
# Out:
# 3

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq.next_()
# Out:
# 4

# %%
sq.next_()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sq.next_()
#
# Cell In[17], line 11, in Squares.next_(self)
#       9     def next_(self):
#      10         if self.i >= self.length:
# ---> 11             raise StopInteration
#      12         else:
#      13             result = self.i ** 2
#      14             self.i += 1
#
# NameError: name 'StopInteration' is not defined

# %%
sq = Squares(3)

# %%
sq = Squares(10)
while True:
    try:
        print(sq.next_())
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
sq.next_()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sq.next_()
#
# Cell In[27], line 11, in Squares.next_(self)
#       9     def next_(self):
#      10         if self.i >= self.length:
# ---> 11             raise StopIteration
#      12         else:
#      13             result = self.i ** 2
#      14             self.i += 1
#
# StopIteration:

# %%
while True:
    try:
        print(sq.next_())
    except StopIteration:
        break

# %%
sq = Squares(10)
while True:
    try:
        print(sq.next_())
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
class Squares:
    def __init__(self, length):
        self.i = 0
        self.length = length

    def __len__(self):
        return self.length
    
    def __next__(self):
        if self.i >= self.length:
            raise StopIteration
        else:
            result = self.i ** 2
            self.i += 1
            return result

# %%
sq = Squares(3)

# %%
next(sq)
# Out:
# 0

# %%
next(sq)
# Out:
# 1

# %%
sq.__next__()
# Out:
# 4

# %%
next(sq)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 next(sq)
#
# Cell In[32], line 11, in Squares.__next__(self)
#       9     def __next__(self):
#      10         if self.i >= self.length:
# ---> 11             raise StopIteration
#      12         else:
#      13             result = self.i ** 2
#      14             self.i += 1
#
# StopIteration:

# %%
sq = Squares(10)
while True:
    try:
        print(next(sq))
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
while True:
    try:
        print(next(sq))
    except StopIteration:
        break

# %%
sq = Squares(10)
for item in sq:
    print(sq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 sq = Squares(10)
# ----> 2 for item in sq:
#       3     print(sq)
#
# TypeError: 'Squares' object is not iterable

# %%
import random

# %%
class RandomNumbers:
    def __init__(self, length, *, range_min=0, range_max=10):
        self.length = length
        self.range_min = range_min
        self.range_max = range_max
        self.num_requested = 0

    def __len__(self):
        return self.length

    def __next__(self):
        if self.num_requested >= self.length:
            raise StopIteration
        else:
            self.num_requested += 1
            return random.randint(self.range_min, self.range_max)

# %%
numbers = RandomNumbers(3)

# %%
next(numbers)
# Out:
# 3

# %%
next(numbers)
# Out:
# 3

# %%
next(numbers)
# Out:
# 9

# %%
next(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 next(numbers)
#
# Cell In[48], line 13, in RandomNumbers.__next__(self)
#      11     def __next__(self):
#      12         if self.num_requested >= self.length:
# ---> 13             raise StopIterations
#      14         else:
#      15             self.num_requested += 1
#      16             return random.randint(self.range_min, self.range_max)
#
# NameError: name 'StopIterations' is not defined

# %%
numbers = RandomNumbers(3)

# %%
print(next(numbers))
print(next(numbers))
print(next(numbers))
# Out:
# 4
# 0
# 8

# %%
print(next(numbers))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print(next(numbers))
#
# Cell In[48], line 13, in RandomNumbers.__next__(self)
#      11     def __next__(self):
#      12         if self.num_requested >= self.length:
# ---> 13             raise StopIterations
#      14         else:
#      15             self.num_requested += 1
#      16             return random.randint(self.range_min, self.range_max)
#
# NameError: name 'StopIterations' is not defined

# %%
numbers = RandomNumbers(10)
while True:
    try:
        print(next(numbers))
    except StopIteration:
        break
# Out:
# 6
# 0
# 0
# 8
# 0
# 7
# 8
# 3
# 4
# 9

# %%
numbers = RandomNumbers(10)

# %%
for number in numbers:
    print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 for number in numbers:
#       2     print(number)
#
# TypeError: 'RandomNumbers' object is not iterable
