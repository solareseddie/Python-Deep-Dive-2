# %% [markdown]
# Introduction

# %% [raw]
# What is an iterable?
# Something that can be iterated over.
# We will see a more formal definition for Python's iterable protocol.
#
# Already seen: Sequences and iteration
# Want a more general way of iteration w/o position fixed
#
# Iterators -> get next item, no indexes needed -> consumables
# Iterables -> collections that implement iterators
# Consuming iterators manually
# Relationship between sequence types and iterators
# Infinite iterables
# Lazy evaluation
# Iterator Delegation
